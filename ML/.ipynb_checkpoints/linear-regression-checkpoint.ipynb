# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('GOOGL.csv')
# https://www.kaggle.com/datasets/aayushmishra1512/google-data-historic-dataset
# this dataset is used to predict closing price of Google stock based on historical data
# features like opening price, high, low, volume data, and dates are used

# %%
data_info = data.info()
data_head = data.head()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4041 entries, 0 to 4040
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4041 non-null   object
#  1   Open       4041 non-null   float64
#  2   High       4041 non-null   float64
#  3   Low        4041 non-null   float64
#  4   Close      4041 non-null   float64
#  5   Adj Close  4041 non-null   float64
#  6   Volume     4041 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 221.1+ KB
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    50.050049    52.082081    48.028027    50.220219
# 1     2004-08-20    50.555557    54.594593    50.300301    54.209209
# 2     2004-08-23    55.430431    56.796795    54.579578    54.754753
# 3     2004-08-24    55.675674    55.855854    51.836838    52.487488
# 4     2004-08-25    52.532532    54.054054    51.991993    53.053055
# ...          ...          ...          ...          ...          ...
# 4036  2020-08-31  1643.569946  1644.500000  1625.329956  1629.530029
# 4037  2020-09-01  1632.160034  1659.219971  1629.530029  1655.079956
# 4038  2020-09-02  1668.010010  1726.099976  1660.189941  1717.390015
# 4039  2020-09-03  1699.520020  1700.000000  1607.709961  1629.510010
# 4040  2020-09-04  1609.000000  1634.989990  1537.970093  1581.209961
#
#         Adj Close    Volume
# 0       50.220219  44659000
# 1       54.209209  22834300
# 2       54.754753  18256100
# 3       52.487488  15247300
# 4       53.053055   9188600
# ...           ...       ...
# 4036  1629.530029   1321100
# 4037  1655.079956   1133800
# 4038  1717.390015   2476100
# 4039  1629.510010   3180200
# 4040  1581.209961   2792533
#
# [4041 rows x 7 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['DateOrdinal'] = data['Date'].map(pd.Timestamp.toordinal)  # number of days since a fixed date, January 1 of year 1 AD
data['DateOrdinal']
# Out:
# 0       731812
# 1       731813
# 2       731816
# 3       731817
# 4       731818
#          ...
# 4036    737668
# 4037    737669
# 4038    737670
# 4039    737671
# 4040    737672
# Name: DateOrdinal, Length: 4041, dtype: int64

# %%
features = ['Open', 'High', 'Low', 'Volume', 'DateOrdinal']
target = 'Close'

random.seed(42)
shuffled = np.random.permutation(len(data))
data_shuffled = data.iloc[shuffled]
n = int(0.9*len(data))  # 90% train, 10% test

# %%
train_data = data_shuffled[:n]
test_data = data_shuffled[n:]

X_train = train_data[features]
y_train = train_data[target]

X_test = test_data[features]
y_test = test_data[target]

# %%
fig, ax = plt.subplots(1, 5, figsize=(20, 4), sharey=True)  # Adjust the figsize to ensure each subplot is clearly visible

for i, feature in enumerate(features):
    ax[i].scatter(X_train[feature], y_train, alpha=0.3)
    ax[i].set_title(f'Scatter plot of {feature} vs. Close Price')
    ax[i].set_xlabel(feature)
    ax[i].set_ylabel('Close Price')

# %%
X_test.shape, y_train.shape
# Out:
# ((405, 5), (3636,))

# %%
scaler = StandardScaler()  # to do the z-score normalization
X_norm = scaler.fit_transform(X_train)

# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 220.62, NNZs: 5, Bias: 533.156079, T: 94536, Avg. loss: 17.832097
# Total training time: 0.02 seconds.
# -- Epoch 27
# Norm: 220.62, NNZs: 5, Bias: 533.237997, T: 98172, Avg. loss: 17.833558
# Total training time: 0.02 seconds.
# -- Epoch 28
# Norm: 220.93, NNZs: 5, Bias: 533.261549, T: 101808, Avg. loss: 17.764631
# Total training time: 0.02 seconds.
# -- Epoch 29
# Norm: 220.68, NNZs: 5, Bias: 533.181419, T: 105444, Avg. loss: 17.804012
# Total training time: 0.02 seconds.
# -- Epoch 30
# Norm: 220.59, NNZs: 5, Bias: 533.219815, T: 109080, Avg. loss: 17.788606
# Total training time: 0.02 seconds.
# -- Epoch 31
# Norm: 220.67, NNZs: 5, Bias: 533.284806, T: 112716, Avg. loss: 17.783981
# Total training time: 0.02 seconds.
# -- Epoch 32
# Norm: 220.77, NNZs: 5, Bias: 533.208069, T: 116352, Avg. loss: 17.800971
# Total training time: 0.02 seconds.
# -- Epoch 33
# Norm: 220.70, NNZs: 5, Bias: 533.191350, T: 119988, Avg. loss: 17.740899
# Total training time: 0.02 seconds.
# -- Epoch 34
# Norm: 220.44, NNZs: 5, Bias: 533.140761, T: 123624, Avg. loss: 17.725534
# Total training time: 0.02 seconds.
# -- Epoch 35
# Norm: 220.77, NNZs: 5, Bias: 533.246935, T: 127260, Avg. loss: 17.702980
# Total training time: 0.02 seconds.
# -- Epoch 36
# Norm: 220.82, NNZs: 5, Bias: 533.251563, T: 130896, Avg. loss: 17.754325
# Total training time: 0.02 seconds.
# -- Epoch 37
# Norm: 220.64, NNZs: 5, Bias: 533.166143, T: 134532, Avg. loss: 17.705566
# Total training time: 0.02 seconds.
# -- Epoch 38
# Norm: 220.83, NNZs: 5, Bias: 533.225597, T: 138168, Avg. loss: 17.738946
# Total training time: 0.02 seconds.
# -- Epoch 39
# Norm: 220.81, NNZs: 5, Bias: 533.195799, T: 141804, Avg. loss: 17.746079
# Total training time: 0.02 seconds.
# -- Epoch 40
# Norm: 220.87, NNZs: 5, Bias: 533.238065, T: 145440, Avg. loss: 17.711757
# Total training time: 0.02 seconds.
# Convergence after 40 epochs took 0.02 seconds
# Number of iterations completed: 40
# model parameters:
# w: [1.23566912e+02 1.28808132e+02 1.30080241e+02 5.50396034e-02
#  9.66648355e-01]
# b = [533.23806483]

# %%
# predict data using trained model
# on train set

# using predict() function
y_pred_sgd = sgdr.predict(X_norm)
# manually calculating using w and b
y_pred = np.dot(X_norm, w_norm) + b_norm

print(f"\nPrediction on training set:\n{y_pred_sgd[:4]}" )
print(f"Target values \n{list(y_train[:4])}")
# Out:
# Prediction on training set:
# [340.06436712 265.45255661 544.75163394  50.71507399]
# Target values
# [340.490479, 263.47348, 539.650024, 52.717716]

# %%
# predict data using trained model
# on test set

X_test_norm = scaler.transform(X_test)
# using predict() function
y_pred_sgd = sgdr.predict(X_test_norm)

print(f"\nPrediction on test set:\n{y_pred_sgd[:5]}" )
print(f"Target values \n{list(y_test[:5])}")
# Out:
# Prediction on test set:
# [1105.82471677  734.32757486  305.27280698 1023.36971603  144.12437043]
# Target values
# [1087.579956, 731.090027, 303.873871, 1011.869995, 145.950958]
